# %% [markdown]
# # TRANSFER LEARNING

# %% [markdown]
# Authors: Joseph Hellerstein & Valentina Staneva & Claude

# %% [markdown]
# This notebook is built on these sources:
#
# * [*Tensorflow Classification Tutorial*](https://www.tensorflow.org/tutorials/images/classification)
#
# * [*Transfer Learning with VGG16 and Keras*](https://towardsdatascience.com/transfer-learning-with-vgg16-and-keras-50ea161580b4),  Medium Blog Post by Gabriel Cassimiro
#
# * [*Tensorflow Transfer Learning Tutorial*](https://www.tensorflow.org/tutorials/images/transfer_learning)
#
# *  https://www.slideshare.net/xavigiro/transfer-learning-d2l4-insightdcu-machine-learning-workshop-2017

# %% [markdown]
# # Summary of Transfer Learning

# %% [markdown]
# Transfer learning is the practice of taking a model that was trained on one task and reusing it — fully or partially — as the starting point for a different task, rather than training from scratch.

# %% [markdown]
# ### The Core Idea
#
# When a CNN like VGG16 is trained on ImageNet, its convolutional layers learn general-purpose visual features that are useful far beyond ImageNet itself:
#
# - **Early layers** learn low-level features: edges, corners, color gradients
# - **Middle layers** learn mid-level features: textures, patterns, simple shapes
# - **Later layers** learn high-level features: eyes, wheels, fur — things specific to the original task
#
# These features turn out to be broadly useful for *any* image recognition task. Rather than relearning them from scratch, transfer learning lets you borrow them.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/joseph-hellerstein/ai_in_practice/main/images/transfer_learning.png" width="750">

# %% [markdown]
# ### Why It Works Well
#
# - **Less data needed**: the conv base already knows how to see; you only need enough data to teach the new head your specific classes
# - **Faster training**: you're only updating a small fraction of parameters
# - **Better results**: especially when your dataset is small, starting from strong pretrained weights almost always outperforms training from scratch

# %% [markdown]
# ### Transfer Learning & Software Engineering

# %% [markdown]
# Transfer learning promotes reuse, reproducibility, and resource efficiency.

# %% [markdown]
# ## Setup
#
# Import TensorFlow and other necessary libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pathlib
import PIL
import tensorflow as tf
import datetime

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import tensorflow.keras.datasets as tfkds
import tensorflow_datasets as tfds
from tensorflow.keras.applications.vgg16 import VGG16
#from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, models
import importlib_resources
from typing import List, Callable

# %%
# set random seed
# tf.keras.utils.set_random_seed(123)

# %%
# set random seed
# tf.keras.utils.set_random_seed(123)
# tf.random.set_seed(123)

# %% [markdown]
# # Helpers

# %%
#(X_TRAIN, Y_TRAIN), (X_TEST, Y_TEST) = tfkds.cifar10.load_data()
(X_TRAIN, Y_TRAIN), (X_TEST, Y_TEST) = keras.datasets.fashion_mnist.load_data()
_, info = tfds.load('fashion_mnist', with_info=True)
LABELS = np.array(info.features['label'].names)

# %% [markdown]
# ## plotAccuracy

# %%
def plotAccuracy(history):
    """
    Plots accuracy over the histor.
    """
    acc = history.history['accuracy'] + history_fine.history['accuracy']
    val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
    epochs_range = range(1, len(history.history['loss'])+ len(history_fine.history['accuracy'])+1)
    # Accuracy
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy: Fine-tuned VGG')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')

# %% [markdown]
# ## plotLabelledImage

# %%
def plotLabelledImage(feature_arr: np.ndarray, label_arr: np.ndarray, num_image=10):
    feature_arr = feature_arr[0:num_image]
    label_arr = label_arr[0:num_image]
    # Plots images and labels
    num_fig = feature_arr.shape[0]
    _, axes = plt.subplots(1, num_fig, figsize=(15,15))
    for idx in range(num_fig):
        ax = axes[idx]
        if feature_arr.ndim == 4:
            ax.imshow(feature_arr[idx, :, :, :].astype("uint8"))
        else:
            ax.imshow(feature_arr[idx, :, :].astype("uint8"))
        ax.axis('off')              # optional: hides the axis ticks
        text = label_arr[idx]
        if not isinstance(text, str):
            text = str(text[0])
        ax.set_title(text, fontsize=8)
    plt.show()

# TESTS
num_image = 10
plotLabelledImage(X_TRAIN, LABELS[Y_TRAIN], num_image=num_image)

# %%
num_pic
# Out:
# 5

# %% [markdown]
# # Flowers Dataset

# %% [markdown]
# This tutorial uses a [dataset](https://www.tensorflow.org/datasets/catalog/tf_flowers) of about 3,700 photos of flowers. The dataset contains five types of flowers:
#
# ```
#   daisy
#   dandelion
#   roses
#   sunflowers
#   tulips
# ```
#
# The goal is to build a classifier which predicts the type of flowers in new images.

# %% [markdown]
# The dataset is part of a collection of [datasets](https://www.tensorflow.org/datasets) in the `tensorflow` library which can be directly loaded.

# %%
# downloading images
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos.tar', origin=dataset_url, extract=True)
data_dir = pathlib.Path(data_dir).with_suffix('')
print(data_dir)

image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# /Users/jlheller/.keras/datasets/flower_photos_extracted
# 0

# %%
ls /root/.keras/datasets/flower_photos_extracted/flower_photos
# Out:
# ls: /root/.keras/datasets/flower_photos_extracted/flower_photos: No such file or directory

# %%
# the images are arranged in folders with their names
list(os.walk(data_dir))[0]
# Out:
# ('/Users/jlheller/.keras/datasets/flower_photos_extracted',
#  ['flower_photos'],
#  [])

# %%
# looking at a few tulips
tulips = list(sorted(data_dir.glob('flower_photos/tulips/*')))
#print(tulips)
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x209>

# %%
PIL.Image.open(str(tulips[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335>

# %% [markdown]
# #### Images are not the same size!

# %% [markdown]
# The images in the dataset are not the same size so we will resize them so that it is easier to put them in an array and process them efficiently. We fix the weight and height to be 150. This resizing can be achieved automatically while reading the data with the `tf.keras.utils.image_dataset_from_directory` function and setting the image size.

# %%
HEIGHT = 150
WIDTH = 150

# %%
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir / "flower_photos",
  validation_split=0.2,
  subset="both",
  labels="inferred",
  label_mode="categorical",
  seed=123,
  image_size=(HEIGHT, WIDTH),
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Using 734 files for validation.

# %% [markdown]
# **Note:** if resizing images in your dataset, you need to select an approach which does not distort substantially your data. The `tf.keras.utils.image_dataset_from_directory` function has some other options such as cropping or padding to aspect ratio.

# %% [markdown]
# ### Hold Out Test Set
# Not we set aside 20% for a test set which we will NOT use in model training and selection. It is easy to overtune the model performance to the specific test we have selected and because we have no more "unseen" data to test on our measures of performance may be skewed. We will only use the test set in the end to evaluate the performance on "unseen" data.

# %%
# convert to numpy arrays
train_images, train_labels = zip(*list(train_ds.unbatch()))
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
list(train_ds.unbatch())[1][1]
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=array([0., 0., 0., 1., 0.], dtype=float32)>

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (2936, 150, 150, 3)
# (2936, 5)

# %% [markdown]
# We loaded the labels in a categorical format, but we also need the class names. These correspond to the directory names in alphabetical order.

# %%
class_names = ["daisy", "dandelion", "roses", "sunflowers","tulips"]
num_classes = len(class_names)

# %% [markdown]
# Let's see the distribution of the classes:

# %%
plt.bar(class_names, train_labels.sum(axis=0))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Visualize the data

# %%
plt.rcParams["figure.figsize"] = [30, 15]
plt.rcParams["figure.autolayout"] = True

counter = 0
for image, label in zip(train_images, train_labels):
  plt.subplot(2, 5, counter+1)
  plt.imshow(image.astype("uint8"))
  label_name = class_names[np.where(label==1)[0][0]]
  plt.title('Label {}'.format(label_name))
  counter += 1
  if counter == 10:
    break

# %% [markdown]
# ### Rescale the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# We can rescale values to be in the `[0, 1]` range by using `tf.keras.layers.Rescaling` in the model definition itself.

# %%
layers.Rescaling(1./255)
# Out:
# <Rescaling name=rescaling, built=False>

# %% [markdown]
# ## CNN Model

# %% [markdown]
# We first build a model for classifying flowers to provide a foundation for transfer learning. Some specifics of the model:
# * Convolutional layers to find image features
# * Dropouts to create a more robust model (and avoid fitting to noise)
# * Data augmentation to handle different orientations of pictures

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=train_images[0,:,:,:].shape),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)
# Out:
# /Users/jlheller/home/Technical/repos/ai_in_practice/aip/lib/python3.11/site-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Data augmentation provides a way to automatically extend the data by having the same image in different rotations.

# %%
plt.rcParams["figure.figsize"] = [30, 15]
plt.rcParams["figure.autolayout"] = True

counter = 0
for image, label in zip(train_images, train_labels):
    plt.subplot(2, 4, counter+1); counter += 1
    plt.imshow(data_augmentation(np.reshape(image, (1, HEIGHT, WIDTH, 3))).cpu().numpy().astype('uint8').squeeze())
    plt.subplot(2, 4, counter+1); counter += 1
    plt.imshow(np.reshape(image, (1, HEIGHT, WIDTH, 3)).astype('uint8').squeeze())
    label_name = class_names[np.where(label==1)[0][0]]
    plt.title('Label {}'.format(label_name))
    if counter == 8:
        break

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.4),

  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.4),

  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.4),

  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.4),

  layers.Dense(num_classes, name="outputs", activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# %%time
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)
epochs=50
history = model.fit(
  train_images,
  train_labels,
  validation_split=0.2,
  epochs=epochs,
  batch_size=32,
  callbacks=[es]
)
# Out:
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 236ms/step - accuracy: 0.2453 - loss: 1.7801 - val_accuracy: 0.2449 - val_loss: 1.5844
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.3109 - loss: 1.5128 - val_accuracy: 0.3401 - val_loss: 1.4972
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 232ms/step - accuracy: 0.4429 - loss: 1.2901 - val_accuracy: 0.4303 - val_loss: 1.3733
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.4651 - loss: 1.2518 - val_accuracy: 0.4898 - val_loss: 1.3002
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.4808 - loss: 1.1945 - val_accuracy: 0.4881 - val_loss: 1.2856
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.5221 - loss: 1.1423 - val_accuracy: 0.5272 - val_loss: 1.2668
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 231ms/step - accuracy: 0.5405 - loss: 1.1413 - val_accuracy: 0.5289 - val_loss: 1.2284
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 231ms/step - accuracy: 0.5443 - loss: 1.1062 - val_accuracy: 0.5187 - val_loss: 1.2032
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 231ms/step - accuracy: 0.5447 - loss: 1.1092 - val_accuracy: 0.5833 - val_loss: 1.1489
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.5490 - loss: 1.0789 - val_accuracy: 0.5697 - val_loss: 1.1594
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.5758 - loss: 1.0597 - val_accuracy: 0.5646 - val_loss: 1.1558
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 232ms/step - accuracy: 0.5852 - loss: 1.0227 - val_accuracy: 0.6054 - val_loss: 1.0901
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 236ms/step - accuracy: 0.6107 - loss: 0.9892 - val_accuracy: 0.6310 - val_loss: 1.0705
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.6193 - loss: 0.9728 - val_accuracy: 0.6412 - val_loss: 1.0202
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.6354 - loss: 0.9444 - val_accuracy: 0.6395 - val_loss: 0.9972
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 231ms/step - accuracy: 0.6444 - loss: 0.8964 - val_accuracy: 0.6378 - val_loss: 0.9919
# Epoch 17/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 242ms/step - accuracy: 0.6495 - loss: 0.8888 - val_accuracy: 0.6548 - val_loss: 0.9459
# Epoch 18/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 244ms/step - accuracy: 0.6665 - loss: 0.8692 - val_accuracy: 0.6616 - val_loss: 0.9108
# Epoch 19/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 243ms/step - accuracy: 0.6657 - loss: 0.8582 - val_accuracy: 0.6616 - val_loss: 0.9072
# Epoch 20/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 245ms/step - accuracy: 0.6665 - loss: 0.8425 - val_accuracy: 0.6752 - val_loss: 0.8632
# Epoch 21/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 246ms/step - accuracy: 0.6836 - loss: 0.8117 - val_accuracy: 0.6871 - val_loss: 0.8528
# Epoch 22/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 235ms/step - accuracy: 0.6848 - loss: 0.7966 - val_accuracy: 0.6735 - val_loss: 0.8881
# Epoch 23/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 235ms/step - accuracy: 0.6814 - loss: 0.8160 - val_accuracy: 0.6939 - val_loss: 0.8271
# Epoch 24/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 232ms/step - accuracy: 0.6929 - loss: 0.7894 - val_accuracy: 0.6616 - val_loss: 0.8441
# Epoch 25/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 231ms/step - accuracy: 0.7006 - loss: 0.8058 - val_accuracy: 0.7007 - val_loss: 0.8023
# Epoch 26/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 236ms/step - accuracy: 0.6912 - loss: 0.7642 - val_accuracy: 0.7007 - val_loss: 0.8173
# Epoch 27/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.7053 - loss: 0.7507 - val_accuracy: 0.7007 - val_loss: 0.8067
# Epoch 28/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 235ms/step - accuracy: 0.7087 - loss: 0.7446 - val_accuracy: 0.7024 - val_loss: 0.8002
# Epoch 29/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.7172 - loss: 0.7332 - val_accuracy: 0.7075 - val_loss: 0.7822
# Epoch 30/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 230ms/step - accuracy: 0.7287 - loss: 0.7201 - val_accuracy: 0.7007 - val_loss: 0.8084
# Epoch 31/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 236ms/step - accuracy: 0.7227 - loss: 0.7208 - val_accuracy: 0.7109 - val_loss: 0.8030
# Epoch 32/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 236ms/step - accuracy: 0.7364 - loss: 0.6993 - val_accuracy: 0.6939 - val_loss: 0.8052
# Epoch 33/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 236ms/step - accuracy: 0.7296 - loss: 0.6995 - val_accuracy: 0.7228 - val_loss: 0.7856
# Epoch 34/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 237ms/step - accuracy: 0.7368 - loss: 0.7028 - val_accuracy: 0.7092 - val_loss: 0.7865
# Epoch 35/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 234ms/step - accuracy: 0.7436 - loss: 0.6684 - val_accuracy: 0.7313 - val_loss: 0.7548
# Epoch 36/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 232ms/step - accuracy: 0.7291 - loss: 0.6803 - val_accuracy: 0.7143 - val_loss: 0.7907
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 237ms/step - accuracy: 0.7521 - loss: 0.6659 - val_accuracy: 0.7313 - val_loss: 0.7812
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.7474 - loss: 0.6561 - val_accuracy: 0.7313 - val_loss: 0.7567
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.7555 - loss: 0.6605 - val_accuracy: 0.7245 - val_loss: 0.7649
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 17s 233ms/step - accuracy: 0.7513 - loss: 0.6350 - val_accuracy: 0.7160 - val_loss: 0.7795
# CPU times: user 4min 55s, sys: 57.5 s, total: 5min 52s
# Wall time: 11min 34s

# %% [markdown]
# We observe that:
# * training accuracy is ~.76
# * validation accuracy is ~.73

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

# %%
# accuracy metrics at each iteration are stored in the history variable
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(history.history['loss'])+1)

# Loss
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss: Data Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# Accuracy
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy: Data Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# The training and validation behavior start to look more similar!

# %% [markdown]
# **Warning!** When doing data augmentation make sure augmented derivatives from the same image do not appear both in your train and validation datasets!

# %% [markdown]
# **Exercise:** Change some of the random transformation parameters and check if there is difference in performance.

# %% [markdown]
# **Exercise:** What other data augmentation techniques can be useful for this problem? Check if they are provided in [Keras](https://keras.io/api/layers/preprocessing_layers/image_augmentation/).

# %% [markdown]
# # Imagenet Model (VGG16)

# %% [markdown]
# VGG16 is a classic deep convolutional neural network developed by the Visual Geometry Group at Oxford University in 2014, and published in the paper *"Very Deep Convolutional Networks for Large-Scale Image Recognition"* by Simonyan and Zisserma. It was a top performer in the ImageNet Large Scale Visual Recognition Challenge (ILSVRC) 2014.

# %% [markdown]
# ### Design Philosophy
#
# The key insight of VGG16 was simplicity and depth: instead of using large kernels (like the 11×11 and 5×5 filters in earlier AlexNet), it stacks many small **3×3 Conv2D layers** with `padding='same'`, which:
# - Keeps the architecture uniform and easy to reason about
# - Uses fewer parameters than larger kernels while achieving the same receptive field
# - Adds more non-linearity (more ReLU activations) which increases expressive power
#
# The "16" in VGG16 refers to the 16 layers that have trainable parameters (13 conv + 3 dense).

# %% [markdown]
# <img src="https://raw.githubusercontent.com/joseph-hellerstein/ai_in_practice/main/images/vgg16.png" width="750">

# %% [markdown]
# ### Architecture
#
# | Block | Layers | Output Shape |
# |---|---|---|
# | Input | — | `(224, 224, 3)` |
# | Block 1 | Conv2D(64) × 2, MaxPool | `(112, 112, 64)` |
# | Block 2 | Conv2D(128) × 2, MaxPool | `(56, 56, 128)` |
# | Block 3 | Conv2D(256) × 3, MaxPool | `(28, 28, 256)` |
# | Block 4 | Conv2D(512) × 3, MaxPool | `(14, 14, 512)` |
# | Block 5 | Conv2D(512) × 3, MaxPool | `(7, 7, 512)` |
# | — | Flatten | `(25088,)` |
# | — | Dense(4096), ReLU | `(4096,)` |
# | — | Dense(4096), ReLU | `(4096,)` |
# | — | Dense(1000), Softmax | `(1000,)` |
#
# All Conv2D layers use `kernel_size=3`, `padding='same'`, and `activation='relu'`. All MaxPooling layers use `pool_size=(2,2)`, which is why spatial dims halve at each block. The final Dense(1000) corresponds to the 1000 ImageNet classes.

# %% [markdown]
# ### Parameter Count
#
# VGG16 has approximately **138 million parameters**, which was large even by 2014 standards. The striking thing is how lopsided the distribution is:
#
# | Section | Params | % of total |
# |---|---|---|
# | All 13 Conv2D layers | ~15M | ~11% |
# | Dense(4096) × 2 + Dense(1000) | ~123M | ~89% |
#
# The two Dense(4096) layers alone account for the vast majority of parameters, which is why modern architectures (ResNet, EfficientNet, etc.) tend to use Global Average Pooling before the classifier head instead of Flatten → Dense, dramatically cutting parameter counts.

# %% [markdown]
# ### Loading VGG16 in Keras
#
# Keras includes VGG16 as a built-in model, optionally with ImageNet pretrained weights:
#
# ```python
#
# model = VGG16(
#     weights='imagenet',   # or None for random init
#     include_top=True,     # False drops the Dense layers, useful for transfer learning
#     input_shape=(224, 224, 3)
# )
#
# model.summary()
# ```

# %% [markdown]
# ### Strengths and Weaknesses
#
# | Strengths | Weaknesses |
# |---|---|
# | Simple, uniform architecture — easy to understand | 138M params — very heavy to train and store |
# | Strong pretrained features, great for transfer learning | Slow inference compared to modern nets |
# | Influenced almost all subsequent CNN designs | No skip connections — deep gradient flow can be difficult |
# | Well studied and documented | Largely superseded by ResNet, EfficientNet, etc. |
#
# Despite its age, VGG16 remains widely used as a **feature extractor** in transfer learning, since its convolutional blocks produce rich, general-purpose image features that transfer well to new tasks.

# %% [markdown]
# # Transfer Learning Using VGG16

# %% [markdown]
# Convolutional Neural Networks can be good feature extractors, i.e. a model trained on one dataset can turn out to be good at extracting useful features from another dataset. This allows deep learning methods to leverage large training sets and be able to generalize to situations where training data can be scarce.
#
# * predict with a pretrained model on new data (zero-shot learning)
# * extract features with a pretrained model and use them to train a shallow classifier on new data
# * fine-tune the trained model to the new data by training with a small learning rate
# * retrain the full model using the pre-trained model weights as initializers
#
# As usual, we will have to evaluate the performance!

# %% [markdown]
# ![TransferLearning](https://drive.google.com/uc?export=view&id=1QF9-eDrTkMouYJdU4k1qCklT3pLCI61u)

# %% [markdown]
# image src = https://www.slideshare.net/xavigiro/transfer-learning-d2l4-insightdcu-machine-learning-workshop-2017

# %% [markdown]
# <img src="https://i.stack.imgur.com/RTKux.png" width="750">

# %% [markdown]
# ### Frozen Pretrained Weights

# %% [markdown]
# Procedure:
#
# * load and initialize a pretrained model
# * remove the top layer
# * freeze the weights of the pretrained model
# * add a top layer(s) linking to our classes
# * train the model
#
# We will use a rather popular architecture VGG16 trained on the huge [Imagenet](https://www.image-net.org/) Dataset.

# %%
## Loading VGG16 model
pretrained_model = VGG16(weights="imagenet", include_top=False, input_shape=(HEIGHT, WIDTH, 3))
pretrained_model.trainable = False ## Not trainable weights

# %%
pretrained_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_37 (InputLayer)     │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 75, 75, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 37, 37, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 18, 18, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# Pretrained models have certain expectations of how the data should look like so that it can be used in the model. They have a corresponding [`preprocess_input`](https://www.tensorflow.org/api_docs/python/tf/keras/applications/vgg16/preprocess_input) model. Make sure you read on the operations in the preprocessing so that it makes sense for your data.

# %%
preprocess_input(train_images.copy()).shape
# Out:
# (2936, 150, 150, 3)

# %% [markdown]
# **Warning!** The `preprocess_input` function changes the input **in-place** hence we need to pass a copy of the images.

# %%
flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(128, activation='relu')
prediction_layer = layers.Dense(5, activation='softmax')


model = models.Sequential([
    pretrained_model,
    flatten_layer,
    dense_layer_1,
    prediction_layer
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,764,037 (60.14 MB)
#  Trainable params: 1,049,349 (4.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

# %%
# %%time
epochs=50
history = model.fit(
  preprocess_input(train_images.copy()),
  train_labels,
  validation_split=0.2,
  epochs=epochs,
  batch_size=32,
  callbacks=[es]
)
# Out:
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.6827 - loss: 4.0553 - val_accuracy: 0.7585 - val_loss: 3.1629
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.8250 - loss: 2.2747 - val_accuracy: 0.7721 - val_loss: 3.0077
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.8603 - loss: 1.8158 - val_accuracy: 0.8044 - val_loss: 2.4318
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.8803 - loss: 1.6040 - val_accuracy: 0.8010 - val_loss: 2.5173
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9063 - loss: 1.2973 - val_accuracy: 0.7959 - val_loss: 2.5479
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9144 - loss: 1.1537 - val_accuracy: 0.8112 - val_loss: 2.3180
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9199 - loss: 1.0890 - val_accuracy: 0.8010 - val_loss: 2.5923
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9319 - loss: 0.9089 - val_accuracy: 0.7976 - val_loss: 2.4281
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9476 - loss: 0.7479 - val_accuracy: 0.8044 - val_loss: 2.4833
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.9485 - loss: 0.6915 - val_accuracy: 0.7959 - val_loss: 2.4565
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9591 - loss: 0.5697 - val_accuracy: 0.7925 - val_loss: 2.4876
# CPU times: user 14.1 s, sys: 2.44 s, total: 16.6 s
# Wall time: 1min 41s

# %% [markdown]
# * training accuracy is very high again: ~0.98
# * validation accuracy is also high: 0.79

# %%
# accuracy metrics at each iteration are stored in the history variable
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(history.history['loss'])+1)

# Loss
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss: Frozen VGG')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# Accuracy
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy: Frozen VGG')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ### Fine-Tune Pretrained Weights

# %% [markdown]
# Fine Tuning:
# * Set the pretrained model to trainable (or some of its layers)
# * Compile the model again
# * Retrain with a small learning rate (0.0001)

# %%
pretrained_model.trainable = True

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,764,037 (60.14 MB)
#  Trainable params: 15,764,037 (60.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)
epochs=50
history_fine = model.fit(
  preprocess_input(train_images.copy()),
  train_labels,
  validation_split=0.2,
  epochs=epochs,
  batch_size=32,
  callbacks=[es]
)
# Out:
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 593ms/step - accuracy: 0.9140 - loss: 1.0710 - val_accuracy: 0.8010 - val_loss: 2.3493
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 594ms/step - accuracy: 0.9293 - loss: 0.9269 - val_accuracy: 0.8044 - val_loss: 2.4123
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 597ms/step - accuracy: 0.9357 - loss: 0.8072 - val_accuracy: 0.8129 - val_loss: 2.1165
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 596ms/step - accuracy: 0.9476 - loss: 0.6137 - val_accuracy: 0.8044 - val_loss: 2.0375
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 598ms/step - accuracy: 0.9544 - loss: 0.4767 - val_accuracy: 0.8095 - val_loss: 1.8264
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 595ms/step - accuracy: 0.9651 - loss: 0.4028 - val_accuracy: 0.8146 - val_loss: 1.6471
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 596ms/step - accuracy: 0.9732 - loss: 0.3511 - val_accuracy: 0.8214 - val_loss: 1.6646
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 597ms/step - accuracy: 0.9774 - loss: 0.3071 - val_accuracy: 0.8197 - val_loss: 1.6559
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 593ms/step - accuracy: 0.9774 - loss: 0.3010 - val_accuracy: 0.8367 - val_loss: 1.7291
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 597ms/step - accuracy: 0.9761 - loss: 0.2885 - val_accuracy: 0.8350 - val_loss: 1.5390
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 599ms/step - accuracy: 0.9842 - loss: 0.2483 - val_accuracy: 0.8418 - val_loss: 1.5187
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 591ms/step - accuracy: 0.9830 - loss: 0.2463 - val_accuracy: 0.8248 - val_loss: 1.5620
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 598ms/step - accuracy: 0.9838 - loss: 0.2440 - val_accuracy: 0.8367 - val_loss: 1.5563
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 595ms/step - accuracy: 0.9851 - loss: 0.2350 - val_accuracy: 0.8316 - val_loss: 1.5221
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 45s 609ms/step - accuracy: 0.9842 - loss: 0.2377 - val_accuracy: 0.8333 - val_loss: 1.5671
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 595ms/step - accuracy: 0.9859 - loss: 0.2269 - val_accuracy: 0.8384 - val_loss: 1.5635
# CPU times: user 28.4 s, sys: 8.71 s, total: 37.1 s
# Wall time: 11min 46s

# %%
# accuracy metrics at each iteration are stored in the history variable

acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']

loss = history.history['loss'] + history_fine.history['loss']
val_loss = history.history['val_loss'] + history_fine.history['val_loss']

# %%
epochs_range = range(1, len(history.history['loss'])+ len(history_fine.history['accuracy'])+1)
print(epochs_range)

# Loss
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.axvline(x = len(history.history['loss'])+1, color = 'g',)
plt.text(len(history.history['loss'])+1,2,'Fine-Tuning Starts',rotation=90, color='g')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss: Fine-tuned VGG')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# Accuracy
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.axvline(x = len(history.history['loss'])+1, color = 'g')
plt.text(len(history.history['loss'])+1, 0.88,'Fine-Tuning Starts',rotation=90, color='g')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy: Fine-tuned VGG')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# range(1, 28)
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# **Exercise:** Retrain full model starting from the imagenet weights (making all weights trainable).

# %% [markdown]
# **Exercise:** Retrain the last 10 layers of the pretrained model + the top layer.
# **Hint:** Use a loop to unfreeze layers.

# %% [markdown]
# Pretrained models can be found:
# * within the [keras library](https://keras.io/api/applications/)
# * on [tensorflow(kaggle) hub](https://www.tensorflow.org/hub)
# * [HuggingFace](https://huggingface.co/models)
# * domain-specific challenges
# * colleagues

# %% [markdown]
# # Transfer Learning With Different Shaped Data

# %% [markdown]
# ### Coniderations for MNIST digits

# %% [markdown]
# * VGG16 expects 3-channel RGB images, but MNIST is grayscale (1 channel) — so I convert/stack the channel.
# * VGG16 expects at least 32×32 input (ideally larger like 48×48 or 224×224), but MNIST images are 28×28. So the MNIST data must be resized.

# %% [markdown]
# Strategy:
# - Preprocess the MNIST data
# - Load VGG16 with `include_top=False` -> this keeps every VGG16 layer
#   EXCEPT the final classification layers (the 3 dense layers, including
#   the last 1000-way softmax layer trained for ImageNet).
# - Freeze those convolutional layers so their pretrained ImageNet weights
#   are preserved.
# - Attach a new, small classification head ending in a 10-way softmax
#   (for digits 0-9).
# - Preprocess MNIST (28x28 grayscale) to be compatible with VGG16
#   (3-channel RGB, min 32x32 — we use 48x48 here for decent feature
#   resolution without being too expensive).

# %% [markdown]
# VGG16 pretrained model
# <img src="https://raw.githubusercontent.com/joseph-hellerstein/ai_in_practice/main/images/vgg16_pretrained_model.png" width="500">

# %% [markdown]
# ### Implementation

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
# -----------------------------
# Config
# -----------------------------
IMG_SIZE = 48          # VGG16 needs >= 32x32; 48x48 is a reasonable, cheap choice
NUM_CLASSES = 10
BATCH_SIZE = 128
EPOCHS_HEAD = 2        # training just the new head
EPOCHS_FINE_TUNE = 2    # optional fine-tuning of top conv block
FINE_TUNE = True        # set False to skip fine-tuning stage

# %%
# -----------------------------
# 1. Load and preprocess MNIST
# -----------------------------
# Using mnist.load_data() directly and preprocessing the full arrays
# eagerly (no tf.data pipeline). This is simpler and fine for a dataset
# MNIST's size, but note it builds the entire resized dataset in memory
# at once: 60000 x 48x48x3 float32 is roughly 1.6GB for the training set.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

def preprocess(x, y):
    # x: (N, 28, 28) uint8 NumPy array -> (N, IMG_SIZE, IMG_SIZE, 3) float32 tensor
    # This runs eagerly now (not inside tf.data.map), so both TF ops and
    # NumPy/Keras-utils functions like to_categorical work fine here.
    x = x[..., np.newaxis]                          # (N, 28, 28) -> (N, 28, 28, 1)
    x = tf.image.resize(x, (IMG_SIZE, IMG_SIZE))    # -> (N, IMG_SIZE, IMG_SIZE, 1)
    x = tf.image.grayscale_to_rgb(x)                # 1 channel -> 3 channels
    x = preprocess_input(x)                         # VGG16-specific preprocessing
    y = tf.keras.utils.to_categorical(y, NUM_CLASSES)  # one-hot encode labels
    return x, y

x_train, y_train = preprocess(x_train, y_train)
x_test, y_test = preprocess(x_test, y_test)

# %%
# -----------------------------
# 2. Load VGG16 base (all layers except the final classification layers)
# -----------------------------
base_model = VGG16(
    weights="imagenet",
    include_top=False,                    # drops the final FC/softmax layers
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Freeze the base model so pretrained weights aren't destroyed by random
# gradients from the new head early in training.
base_model.trainable = False

# %%
# -----------------------------
# 3. Build the new model: VGG16 base + custom head for 10-digit classification
# -----------------------------
inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# -----------------------------
# 4. Train the new head (base frozen)
# -----------------------------
print("\n=== Stage 1: Training classification head (VGG16 base frozen) ===")
history_head = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS_HEAD
)
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_36 (InputLayer)     │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 1, 1, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_14     │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,586 (56.64 MB)
#  Trainable params: 133,898 (523.04 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# === Stage 1: Training classification head (VGG16 base frozen) ===
# Epoch 1/2
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 29s 61ms/step - accuracy: 0.7956 - loss: 1.0973 - val_accuracy: 0.9333 - val_loss: 0.2293
# Epoch 2/2
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.8988 - loss: 0.3208 - val_accuracy: 0.9441 - val_loss: 0.1805

# %%
# -----------------------------
# 5. (Optional) Fine-tune the top conv block of VGG16
# -----------------------------
if FINE_TUNE:
    print("\n=== Stage 2: Fine-tuning top VGG16 conv block ===")
    base_model.trainable = True

    # Retrain the blocks starting with block5_conv1
    # low-level pretrained features and to keep training cheap.
    fine_tune_at = "block5_conv1"
    set_trainable = False
    for layer in base_model.layers:
        if layer.name == fine_tune_at:
            set_trainable = True
        layer.trainable = set_trainable

    # Use a much lower learning rate for fine-tuning
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    history_finetune = model.fit(
        x_train, y_train,
        validation_data=(x_test, y_test),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS_FINE_TUNE
    )

# -----------------------------
# 6. Evaluate
# -----------------------------
test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print(f"\nFinal test accuracy: {test_acc:.4f}")

# -----------------------------
# 7. Save the model
# -----------------------------
model.save("vgg16_mnist_transfer.keras")
print("Model saved to vgg16_mnist_transfer.keras")
# Out:
# === Stage 2: Fine-tuning top VGG16 conv block ===
# Epoch 1/2
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 36s 75ms/step - accuracy: 0.9566 - loss: 0.1409 - val_accuracy: 0.9808 - val_loss: 0.0662
# Epoch 2/2
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - accuracy: 0.9774 - loss: 0.0751 - val_accuracy: 0.9854 - val_loss: 0.0508
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9854 - loss: 0.0508
#
# Final test accuracy: 0.9854
# Model saved to vgg16_mnist_transfer.keras

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, y_train = preprocess(x_train, y_train)
x_test, y_test = preprocess(x_test, y_test)

test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - accuracy: 0.9854 - loss: 0.0508

# %% [markdown]
# Preparing the data
# * Select correct model
# * Reshape the input data
# * Adjust the softmax layer

# %% [markdown]
# # Selecting the Right Base Model for Transfer Learning

# %% [markdown]
# Consider a different dataset, the MNIST Fashion Data

# %%
(x_train, y_train), (x_test, y_test) = tfkds.cifar100.load_data()
_, info = tfds.load('cifar100', with_info=True)
label_arr = np.array(info.features['label'].names)
plotLabelledImage(x_train, label_arr[y_train], num_image=15)

# %% [markdown]
# ### Prepare data

# %% [markdown]
# There's one big mismatch to address upfront: VGG16 expects (224, 224, 3) RGB input, but MNIST images are (32, 32, 3). You have to handle both issues — size and channels.

# %%
NEW_HEIGHT = 32
NEW_WIDTH = 32

x_train_nrml = x_train / 255.0
x_test_nrml  = x_test  / 255.0

# %% [markdown]
# ### Build the model

# %%
from keras.applications import MobileNetV2, EfficientNetV2L, MobileNetV2, EfficientNetB7, DenseNet169, NASNetLarge, ConvNeXtLarge,ResNet50V2
BASE_MODEL_TYPES = [VGG16, MobileNetV2, EfficientNetV2L, MobileNetV2, EfficientNetB7,  DenseNet169, NASNetLarge, ConvNeXtLarge,ResNet50V2]

# %%
def getBestBaseModel(base_model_types: List[Callable], x_train_nrml: np.ndarray, y_train: np.ndarray,
            num_epoch: int = 2, num_sample: int = -1) -> Callable:
    """
    Finds the base model for the flowers data that gives the highest val_accuracy after a specified number of epochs

    Args:
        base_model_types - list of base models in keras.applications
        x_train_nrml - feature data normalized between 0 and 1
        y_train - label index
        num_epoch - number of epochs to run
        num_sample - number of samples to randomly select from the arrays. -1 is all.

    Returns:
        base model
    """
    num_row = x_train_nrml.shape[0]
    if num_sample > 0:
        indices = np.array(range(num_row))
        indices = np.random.permutation(indices)
        indices = indices[:num_sample]
        x_train_nrml = x_train_nrml[indices]
        y_train = y_train[indices]
    best_model_type = None
    best_model = None
    best_model_accuracy = 0
    # Loop across all models
    for model_type in base_model_types:
        print("*** " + str(model_type))
        base_model = model_type(weights='imagenet', include_top=False, input_shape=(NEW_HEIGHT, NEW_WIDTH, 3))
        base_model.trainable = False  # freeze the convolutional base
    
        model = models.Sequential([
            base_model,
        layers.GlobalAveragePooling2D(),
        #layers.Dense(512, activation='relu'),
        layers.Dense(256, activation='relu'),
        layers.Dense(100, activation='softmax')   # 10 classes for digits 0-9
        ])
        #
        model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',  # use this when labels are integers
        metrics=['accuracy']
        )
        #
        es = EarlyStopping(monitor='val_accuracy', mode='max', patience=2,  restore_best_weights=True, min_delta=0.01)
        history = model.fit(
            x_train_nrml, y_train,
            epochs=num_epoch,
            batch_size=32,
            validation_split=0.1,
            callbacks=[es],
        )
        # Update the accuracy info if needed
        current_accuracy =  history.history['val_accuracy'][-1]
        if best_model_type is None:
            best_model_type = model_type
            best_model = model
            best_model_accuracy = current_accuracy
            print(f"Set {str(best_model_type)} with accuracy {best_model_accuracy}")
        elif current_accuracy > best_model_accuracy:
            best_model_type = model_type
            best_model = model
            best_model_accuracy = current_accuracy
            print(f"Set {str(best_model_type)} with accuracy {best_model_accuracy}")

#
getBestBaseModel(BASE_MODEL_TYPES, x_train_nrml, y_train, num_epoch=5, num_sample=400)
# Out:
# *** <function VGG16 at 0x12b99eac0>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.0167 - loss: 4.6614 - val_accuracy: 0.0750 - val_loss: 4.4791
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0917 - loss: 4.1621 - val_accuracy: 0.0500 - val_loss: 4.4987
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1861 - loss: 3.8286 - val_accuracy: 0.0750 - val_loss: 4.4576
# Set <function VGG16 at 0x12b99eac0> with accuracy 0.07500000298023224
# *** <function MobileNetV2 at 0x12b99c720>
# /var/folders/02/lb248q1j50dch2pthzkvxmpr0000gn/T/ipykernel_38660/3888333850.py:29: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = model_type(weights='imagenet', include_top=False, input_shape=(NEW_HEIGHT, NEW_WIDTH, 3))
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.0306 - loss: 4.5944 - val_accuracy: 0.0000e+00 - val_loss: 4.6207
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.1028 - loss: 4.4640 - val_accuracy: 0.0000e+00 - val_loss: 4.6017
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.1750 - loss: 4.3490 - val_accuracy: 0.0250 - val_loss: 4.5876
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.2000 - loss: 4.2247 - val_accuracy: 0.0250 - val_loss: 4.5804
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.2444 - loss: 4.0941 - val_accuracy: 0.0500 - val_loss: 4.5813
# *** <function EfficientNetV2L at 0x12b96b6a0>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 494ms/step - accuracy: 0.0278 - loss: 4.7045 - val_accuracy: 0.0500 - val_loss: 4.6437
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.0222 - loss: 4.5524 - val_accuracy: 0.0000e+00 - val_loss: 4.6830
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - accuracy: 0.0250 - loss: 4.5104 - val_accuracy: 0.0500 - val_loss: 4.6998
# *** <function MobileNetV2 at 0x12b99c720>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.0194 - loss: 4.6013 - val_accuracy: 0.0250 - val_loss: 4.6071
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.1028 - loss: 4.4718 - val_accuracy: 0.0750 - val_loss: 4.5904
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.1444 - loss: 4.3583 - val_accuracy: 0.0750 - val_loss: 4.5693
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.1972 - loss: 4.2364 - val_accuracy: 0.0500 - val_loss: 4.5596
# *** <function EfficientNetB7 at 0x12b96aca0>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 432ms/step - accuracy: 0.0194 - loss: 11.8172 - val_accuracy: 0.0250 - val_loss: 11.5430
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 461ms/step - accuracy: 0.0083 - loss: 10.0769 - val_accuracy: 0.0250 - val_loss: 10.4212
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 409ms/step - accuracy: 0.0222 - loss: 9.0284 - val_accuracy: 0.0000e+00 - val_loss: 10.2562
# *** <function DenseNet169 at 0x12b96a480>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.0250 - loss: 4.6827 - val_accuracy: 0.1250 - val_loss: 4.6087
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.3028 - loss: 3.5237 - val_accuracy: 0.1000 - val_loss: 4.5200
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.5583 - loss: 2.7143 - val_accuracy: 0.1500 - val_loss: 4.3858
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.7083 - loss: 2.0083 - val_accuracy: 0.1500 - val_loss: 4.2698
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.8444 - loss: 1.4183 - val_accuracy: 0.1750 - val_loss: 4.2222
# Set <function DenseNet169 at 0x12b96a480> with accuracy 0.17499999701976776
# *** <function NASNetLarge at 0x12b99d440>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 0.0250 - loss: 4.7424 - val_accuracy: 0.0250 - val_loss: 4.6845
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - accuracy: 0.0278 - loss: 4.4731 - val_accuracy: 0.0250 - val_loss: 4.6749
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 372ms/step - accuracy: 0.0500 - loss: 4.3658 - val_accuracy: 0.0250 - val_loss: 4.7415
# *** <function ConvNeXtLarge at 0x12b969ee0>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.0194 - loss: 4.8814 - val_accuracy: 0.0000e+00 - val_loss: 4.6140
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.0222 - loss: 4.5298 - val_accuracy: 0.0250 - val_loss: 4.6300
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.0389 - loss: 4.4402 - val_accuracy: 0.0250 - val_loss: 4.6823
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.0306 - loss: 4.3894 - val_accuracy: 0.0500 - val_loss: 4.6263
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.0722 - loss: 4.3669 - val_accuracy: 0.0500 - val_loss: 4.6861
# *** <function ResNet50V2 at 0x12b99e5c0>
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.0083 - loss: 4.6819 - val_accuracy: 0.0250 - val_loss: 4.5204
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.2417 - loss: 4.0587 - val_accuracy: 0.0250 - val_loss: 4.5204
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.3750 - loss: 3.6948 - val_accuracy: 0.0750 - val_loss: 4.5177
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.4333 - loss: 3.3665 - val_accuracy: 0.0750 - val_loss: 4.5850
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.5278 - loss: 3.0513 - val_accuracy: 0.1000 - val_loss: 4.7102

# %% [markdown]
# | Model | Train Time (sec) | Accuracy |
# |-------|------------:|----------:|
# | VGG16 | 150 | 0.34 |
# | MovileNetV2 | 360 | 0.13 |
# | EfficientNetV2L | 1,600 | 0.07 |
# | MobileNetV2 | 355 | 0.14 |
# | EfficientNetB7 | 1,305 | 0.07 |
# | DenseNet169 | 1,065 | 0.38 |
# | NASNNetLarge | 1,104 | 0.04 |
# | ConvNeXtLarge | 490 | 0.08 |
# | ResNet50V2 | 344 | 0.16 |

# %%
# Load VGG16 without the top Dense layers, with ImageNet weights
#base_model = VGG16(weights='imagenet', include_top=False, input_shape=(NEW_HEIGHT, NEW_WIDTH, 3))
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(NEW_HEIGHT, NEW_WIDTH, 3))
base_model.trainable = False  # freeze the convolutional base

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(100, activation='softmax')   # 10 classes for digits 0-9
])

model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 1, 1, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_10     │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,134,372 (57.73 MB)
#  Trainable params: 419,684 (1.60 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ### Compile and Train

# %% [markdown]
# We use early stopping to detect when accuracy is not improving significantly.

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',  # use this when labels are integers
    metrics=['accuracy']
)
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=2,  restore_best_weights=True, min_delta=0.01)
history = model.fit(
    x_train_nrml, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.1,
    callbacks=[es],
)
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 25ms/step - accuracy: 0.3144 - loss: 2.6994 - val_accuracy: 0.3098 - val_loss: 2.7719
# Epoch 2/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.3533 - loss: 2.5023 - val_accuracy: 0.3204 - val_loss: 2.6833
# Epoch 3/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3885 - loss: 2.3468 - val_accuracy: 0.3350 - val_loss: 2.6654
# Epoch 4/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.4181 - loss: 2.2039 - val_accuracy: 0.3444 - val_loss: 2.6671
# Epoch 5/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.4466 - loss: 2.0738 - val_accuracy: 0.3446 - val_loss: 2.6791

# %% [markdown]
# ### Assessing the results

# %%
# Returns probabilities for each class, shape (num_samples, num_classes)
y_pred_probs = model.predict(x_test_nrml)

# Convert probabilities to class labels by taking the argmax
y_pred = np.argmax(y_pred_probs, axis=1)

# Plot the result
num_pic = 15
plotImage(x_test[0:num_pic, :, :], fine_labels[y_pred[0:num_pic]])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step

# %%
fine_labels[y_pred[0:num_pic]]
# Out:
# array(['spider', 'tiger', 'tractor', 'tractor', 'sea', 'bee', 'house',
#        'skunk', 'sea', 'tulip', 'table', 'cockroach', 'train', 'mountain',
#        'table'], dtype='<U13')

# %% [markdown]
# ## Notes

# %% [markdown]
# 1. Refine example of transfer learning with fashion. How get good performance?
# 2. Get MNIST example back so see data transformations.
# 3. Compare transfer learning with different base models
# 4. Do fine-tuned weights
# 5. Flesh out the topics
