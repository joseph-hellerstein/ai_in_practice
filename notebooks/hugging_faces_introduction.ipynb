# %% [markdown]
# # HUGGING FACES INTRODUCTION

# %% [markdown]
# # References

# %% [markdown]
# * https://dev.to/pavanbelagatti/hugging-face-101-a-tutorial-for-absolute-beginners-3b0l

# %% [markdown]
# # Creating a Hugging Face Account and API Key

# %% [markdown]
# * Account
# * API key
# * Running a simple script
